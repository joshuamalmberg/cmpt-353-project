# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy import signal, stats
from math import sqrt

def read_csv(directory_name , fileName):
    '''
    Read the file from a directory given directory name and file name, we collected all the data in one directory 
    '''
    read_file = 'data/' + directory_name + '/' + fileName + '.csv'
    df = pd.read_csv(read_file)                                           
                                                     
    #df = df[ (df['time'] >= 2) & (df['time'] <= 6) ]                      
            
    return df                                                             

def get_dataFrame():
    #speed 0 for walk 1 for run
    master_df = pd.DataFrame(columns=["Timestamp", "gx", "gy", "gz", "ax", "ay", "az", "speed", "location"])
    for i in range(1):
        data = read_csv('run_leftleg' , 'run-leftleg-' + str(1))
        #data_feature = butterworth(data)
        data["speed"] = 1
        data["location"] = 0
        master_df = master_df.append(data)

    for i in range(1):
        data = read_csv('run_rightleg' , 'run-rightleg-' + str(1))
        #data_feature = butterworth(data)
        data["speed"] = 1
        data["location"] = 1
        master_df = master_df.append(data)

    for i in range(1):
        data = read_csv('run_lefthand' , 'run-lefthand-' + str(1))
        #data_feature = butterworth(data)
        data["speed"] = 1
        data["location"] = 2
        master_df = master_df.append(data)

    for i in range(1):
        data = read_csv('run_righthand' , 'run-righthand-' + str(1))
        #data_feature = butterworth(data)
        data["speed"] = 1
        data["location"] = 3
        master_df = master_df.append(data)

    for i in range(1):
        data = read_csv('walk_leftleg' , 'walk-leftleg-' + str(1))
        #data_feature = butterworth(data)
        data["speed"] = 0
        data["location"] = 0
        master_df = master_df.append(data)

    for i in range(1):
        data = read_csv('walk_rightleg' , 'walk-rightleg-' + str(1))
        #data_feature = get_basic_feature_butterworth(data)
        data["speed"] = 0
        data["location"] = 1
        master_df = master_df.append(data)

    for i in range(1):
        data = read_csv('walk_lefthand' , 'walk-lefthand-' + str(1))
        #data_feature = butterworth(data)
        data["speed"] = 0
        data["location"] = 2
        master_df = master_df.append(data)

    for i in range(1):
        data = read_csv('walk_righthand' , 'walk-righthand-' + str(1))
        #data_feature = butterworth(data)
        data["speed"] = 1
        data["location"] = 3
        master_df = master_df.append(data)

    #columns = ['ax' , 'ay' , 'az' , 'aT' ]
                   
    return master_df

df apply_butterworth(df):
    b,a = signal.butter(3, 0.08, btype='lowpass', analog=False)
    df["ay"] = signal.filtfilt(b,a, df["ay"])
    df["ax"] = signal.filtfilt(b,a, df["ax"])
    df["az"] = signal.filtfilt(b,a, df["az"])

# %%
df = get_dataFrame()
df
# Out:
#                      Timestamp        gx        gy        gz        ax  \
# 0     2020-12-01 18:41:13.1520 -0.124088 -0.600697  0.380133  0.133545
# 1     2020-12-01 18:41:13.1630 -0.124088 -0.600697  0.380133  0.133545
# 2     2020-12-01 18:41:13.1840 -0.233138 -0.263716  0.334171 -0.064758
# 3     2020-12-01 18:41:13.2170  0.017165  0.790480  0.196635 -0.126999
# 4     2020-12-01 18:41:13.2350  0.079562  0.258636  0.270309  0.068802
# ...                        ...       ...       ...       ...       ...
# 1538  2020-12-01 18:34:05.4670 -0.025317  0.891412  0.052733  0.082306
# 1539  2020-12-01 18:34:05.4880 -0.251995  0.950094 -0.160527  0.170776
# 1540  2020-12-01 18:34:05.4990 -0.251995  0.950094 -0.160527  0.132874
# 1541  2020-12-01 18:34:05.5210 -0.460066  0.616257 -0.568328  0.423660
# 1542  2020-12-01 18:34:05.5500 -0.574549 -0.338753  0.241481  0.440720
#
#             ay        az speed location
# 0    -0.934067 -0.380096     1        0
# 1    -0.934067 -0.380096     1        0
# 2    -0.861557 -0.367569     1        0
# 3    -0.999634 -0.105820     1        0
# 4    -1.017624 -0.191483     1        0
# ...        ...       ...   ...      ...
# 1538 -0.484985 -1.248276     1        3
# 1539 -0.456360 -1.037979     1        3
# 1540 -0.285904 -1.179413     1        3
# 1541 -0.407257 -1.165848     1        3
# 1542 -0.443649 -1.228806     1        3
#
# [9325 rows x 9 columns]

# %%
b,a = signal.butter(4, 0.08, btype='lowpass', analog=False)
low_passed = signal.filtfilt(b,a, df["ay"])
low_passed
# Out:
# array([-0.93533219, -0.94203878, -0.94862823, ..., -0.49134671,
#        -0.47817476, -0.46436425])

# %%
plt.plot(df["Timestamp"].iloc[0:200], df["ay"].iloc[8000:8200], "b.-")
plt.plot(df["Timestamp"].iloc[0:200], low_passed[8000:8200], "r-")
plt.show()
